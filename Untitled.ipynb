# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("Bullly.jpeg")
plt.imshow(img)

# %%
filter = np.random.random((img.shape[0],img.shape[1]))
gaussian = np.random.normal(size = (img.shape[0],img.shape[1]))

# %%
gaussian.shape

# %%
new_image = []
new_image += [np.array(img[:,:,i]) * gaussian**1/100 for i in range(3)] 
np.array(new_image).shape
# Out:
# (3, 400, 600)

# %%
plt.imshow(np.array(new_image).transpose(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
np.array(new_image).transpose(1,2,0).shape
# Out:
# (400, 600, 3)

# %%
import torch

# %%
plt.imshow(torch.normal(torch.ones(100,100)))
